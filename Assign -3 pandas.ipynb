# %%
    

Assignments on HR Data


	
Convert average_montly_hours into days & hours
	Give hike to people still with company & did in top 25%ile of performance


Assignments on Titanic Data


	
Create a new column with values KID,ADULT & OLD based on age
	Find the ichest person

# %%
import pandas as pd
import numpy as np

# %%
###HR DATA

# %%
hr_data = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/HR_comma_sep.csv.txt')
hr_data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
###1.	Give hike to people still with company & did in top 25%ile of performance

# %%
hr_data[(hr_data.last_evaluation > 0.87) & (hr_data.left == 1)]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2                    0.11             0.88               7
# 8                    0.89             1.00               5
# 12                   0.84             0.92               4
# 17                   0.78             0.99               4
# 19                   0.76             0.89               5
# ...                   ...              ...             ...
# 14980                0.76             0.89               5
# 14981                0.73             0.93               5
# 14985                0.91             0.99               5
# 14990                0.89             0.88               5
# 14997                0.11             0.96               6
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 2                       272                   4              0     1
# 8                       224                   5              0     1
# ...

# %%
hr_data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
###2.Convert average_montly_hours into days & hours

# %%
def f(r):
    return (str(r//24)+ "days"+ str(r%24)+"hours")
hr_data["Work_hours"] = hr_data.average_montly_hours.map(f)
hr_data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
def f(r):
    return (str(r.average_montly_hours//24)+ "days"+ str(r.average_montly_hours%24)+"hours")
hr_data["Work_hours"] = hr_data.apply(f, axis = 1)
hr_data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
t_data = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/titanic-train.csv.txt', index_col='PassengerId')
t_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
###3.new column with values KID,ADULT & OLD based on age

# %%
def f(r):
    if r.Age < 20:
        return "Child"
    elif r.Age>20 and r.Age<40:
        return "Adult"
    elif r.Age> 40:
        return "OLD"
t_data["Age_type"] = t_data.apply(f, axis =1)

# %%
t_data.head(111)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 107                 1       3
# 108                 1       3
# 109                 0       3
# 110                 1       3
# 111                 0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
t_data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
###4. max age of the person in the ship

# %%
t_data[t_data.Age== 80]
# Out:
#              Survived  Pclass                                  Name   Sex  \
# PassengerId
# 631                 1       1  Barkworth, Mr. Algernon Henry Wilson  male
#
#               Age  SibSp  Parch Ticket  Fare Cabin Embarked Age_type
# PassengerId
# 631          80.0      0      0  27042  30.0   A23        S      OLD
