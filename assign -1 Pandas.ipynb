# %%
import pandas as pd

# %% [markdown]
# ###
# 1. Create a dataframe fruit_sales that matches the diagram below:
#             Apple    Bananas
# 2017 Sales     30    21
# 2018 Sales     41    34

# %%
s1 = pd.Series([30,41], index = ["2017 sales","2018 sales"])
s2 = pd.Series([21,34], index = ["2017 sales","2018 sales"])
pd.DataFrame({"Apple":s1,"Bannas":s2})
# Out:
#             Apple  Bannas
# 2017 sales     30      21
# 2018 sales     41      34

# %%
2. Create a variable ingredients with a Series that looks like:
Flour     4 cups
Milk       1 cup
Eggs     2 large
Spam       1 can

# %%
s1 = pd.Series([4,1,2,1], index = ["Flour","milk","Eggs","Spam"])
s2 = pd.Series(["cups","cup","Large","can"], index = ["Flour","milk","Eggs","Spam"])
pd.DataFrame({"Capacity":s1,"Type":s2})
# Out:
#        Capacity   Type
# Flour         4   cups
# milk          1    cup
# Eggs          2  Large
# Spam          1    can

# %%
3. Create a dataframe from series that looks like
    A    B
a    1    11

b    2    22

c    3    33

d    4    44

e    5    55

# %%
s1 = pd.Series([1,2,3,4,5], index = ["a","b","c","d","e"])
s2 = pd.Series([11,22,33,44,55], index = ["a","b","c","d","e"])
pd.DataFrame({"C1":s1,"C2":s2})
# Out:
#    C1  C2
# a   1  11
# b   2  22
# c   3  33
# d   4  44
# e   5  55

# %%
4. Create a dataframe using random numpy array that look like:
    a   b    c    d    e
A   [
B          Some
C          random 
D          values
E                      ]

# %%
s1 = pd.Series(["[","","","",""], index = ["A","B","C","D","E"])
s2 = pd.Series(["","","","",""], index = ["A","B","C","D","E"])
s3 = pd.Series(["","some","random","values",""], index = ["A","B","C","D","E"])
s4 = pd.Series(["","","","",""], index = ["A","B","C","D","E"])
s5 = pd.Series(["","","","","]"], index = ["A","B","C","D","E"])
pd.DataFrame({"a":s1,"b":s2,"c":s3,"d":s4,"e":s5})
# Out:
#    a b       c d  e
# A  [
# B         some
# C       random
# D       values
# E                 ]

# %% [markdown]
# ###5. Read a csv file and display data of file and assign it to variable csv.
# Level : Easy

# %%
tt = pd.read_csv("https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/titanic-train.csv.txt")
tt
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ###6. Select the description column from csv and assign the result to the variable desc.¶

# %%
import pandas as pd
s = pd.read_csv("https://raw.githubusercontent.com/edyoda/Data-Scientist-program/master/Practice%20Problems/data/winemag.csv", encoding="latin")
desc = s[["description"]]
desc
# Out:
#                                               description
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129863                                                NaN
# 129864                                                NaN
# 129865                                                NaN
# 129866                                                NaN
# 129867                                                NaN
#
# [129868 rows x 1 columns]

# %%
###7. Select the first value from the description column of csv, assigning it to variable first_description.

# %%
# import pandas as pd
s = pd.read_csv("https://raw.githubusercontent.com/edyoda/Data-Scientist-program/master/Practice%20Problems/data/winemag.csv", encoding="latin")
desc = s[["description"]].head(1)
desc
# Out:
#                                          description
# 0  Aromas include tropical fruit, broom, brimston...

# %%
8. Select the first 10 values from the description column in reviews, assigning the result to variable first_descriptions.

# %%
# import pandas as pd
s = pd.read_csv("https://raw.githubusercontent.com/edyoda/Data-Scientist-program/master/Practice%20Problems/data/winemag.csv", encoding="latin")
first_ten = s[["description"]].head(10)
first_ten
# Out:
#                                          description
# 0  Aromas include tropical fruit, broom, brimston...
# 1  This is ripe and fruity, a wine that is smooth...
# 2  Tart and snappy, the flavors of lime flesh and...
# 3  Pineapple rind, lemon pith and orange blossom ...
# 4  Much like the regular bottling from 2012, this...
# 5  Blackberry and raspberry aromas show a typical...
# 6  Here's a bright, informal red that opens with ...
# 7  This dry and restrained wine offers spice in p...
# 8  Savory dried thyme notes accent sunnier flavor...
# 9  This has great depth of flavor with its fresh ...

# %%
####9. Select the records with index labels 1, 2, 3, 5, and 8, assigning the result to the variable sample_reviews.
Level : Medium

# %%
import pandas as pd
s = pd.read_csv("https://raw.githubusercontent.com/edyoda/Data-Scientist-program/master/Practice%20Problems/data/winemag.csv", encoding="latin")
Sample_viewa = s.iloc[[1,2,3,4,5,8]]
Sample_viewa

# for single specified row
# Out:
#    Unnamed: 0   country                                        description  \
# 1         1.0  Portugal  This is ripe and fruity, a wine that is smooth...
# 2         2.0        US  Tart and snappy, the flavors of lime flesh and...
# 3         3.0        US  Pineapple rind, lemon pith and orange blossom ...
# 4         4.0        US  Much like the regular bottling from 2012, this...
# 5         5.0     Spain  Blackberry and raspberry aromas show a typical...
# 8         8.0   Germany  Savory dried thyme notes accent sunnier flavor...
#
#                           designation  points  Unnamed: 5        province  \
# 1                            Avidagos    87.0         NaN           Douro
# 2                                 NaN    87.0         NaN          Oregon
# 3                Reserve Late Harvest    87.0         NaN        Michigan
# 4  Vintner's Reserve Wild Child Block    87.0         NaN          Oregon
# ...

# %%
10. Create a variable df containing the country, province, region_1, and region_2 columns of the records with the index labels 0, 1, 10, and 100.

# %%
import pandas as pd
s.loc[[0,1,10,100],["country","province","region_1","region_2"]]
# Out:
#       country           province      region_1      region_2
# 0       Italy  Sicily & Sardinia          Etna           NaN
# 1    Portugal              Douro           NaN           NaN
# 10         US         California   Napa Valley          Napa
# 100        US           New York  Finger Lakes  Finger Lakes

# %%
###11
11. Create a DataFrame top_oceania_wines containing all reviews with at least 95 points (out of 100) for wines from Australia or New Zealand.
Level: Hard

# %%
s.describe()
a = s[(s.points>95)& (s.country == "Australia") ]
a
# Out:
#        Unnamed: 0    country  \
# 345         345.0  Australia
# 346         346.0  Australia
# 348         348.0  Australia
# 349         349.0  Australia
# 34502     34502.0  Australia
# 34506     34506.0  Australia
# 39961     39961.0  Australia
# 56953     56953.0  Australia
# 56956     56956.0  Australia
# 56957     56957.0  Australia
# 56959     56959.0  Australia
# 59977     59977.0  Australia
# 67096     67096.0  Australia
# 77028     77028.0  Australia
# 77036     77036.0  Australia
# 77037     77037.0  Australia
#
#                                              description  \
# 345    This wine contains some material over 100 year...
# 346    This deep brown wine smells like a damp, mossy...
# 348    Deep mahogany. Dried fig and black tea on the ...
# 349    RunRig is always complex, and the 2012 doesn't...
# 34502  This prodigious wine showcases Barossa's abili...
# 34506  If Standish's Relic is the feminine side of Sh...
# ...

# %%
a.sort_values(by = ['points'] , ascending=False)
# Out:
#        Unnamed: 0    country  \
# 345         345.0  Australia
# 56953     56953.0  Australia
# 346         346.0  Australia
# 34502     34502.0  Australia
# 67096     67096.0  Australia
# 77028     77028.0  Australia
# 348         348.0  Australia
# 349         349.0  Australia
# 56956     56956.0  Australia
# 34506     34506.0  Australia
# 39961     39961.0  Australia
# 56957     56957.0  Australia
# 56959     56959.0  Australia
# 59977     59977.0  Australia
# 77036     77036.0  Australia
# 77037     77037.0  Australia
#
#                                              description  \
# 345    This wine contains some material over 100 year...
# 56953  This inky, embryonic wine deserves to be cella...
# 346    This deep brown wine smells like a damp, mossy...
# 34502  This prodigious wine showcases Barossa's abili...
# 67096  Just a tiny serving of this dark nectar will l...
# 77028  This has all the size and weight you've come t...
# ...

# %%
###13. Select all record of Itly and point less than 80 using where clause.

# %%
s.where((s.country == "Italy")& (s.points <80)).head()
# Out:
#    Unnamed: 0 country description designation  points  Unnamed: 5 province  \
# 0         NaN     NaN         NaN         NaN     NaN         NaN      NaN
# 1         NaN     NaN         NaN         NaN     NaN         NaN      NaN
# 2         NaN     NaN         NaN         NaN     NaN         NaN      NaN
# 3         NaN     NaN         NaN         NaN     NaN         NaN      NaN
# 4         NaN     NaN         NaN         NaN     NaN         NaN      NaN
#
#   region_1 region_2  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 0      NaN      NaN         NaN          NaN          NaN
# 1      NaN      NaN         NaN          NaN          NaN
# 2      NaN      NaN         NaN          NaN          NaN
# 3      NaN      NaN         NaN          NaN          NaN
# 4      NaN      NaN         NaN          NaN          NaN
