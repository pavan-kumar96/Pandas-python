# %%
import pandas as pd

# %%
s1 = pd.Series([1,2,3,4], index = ["a","b","c","d"])

# %%
s2 = pd.Series([1,2,3,4], index = ["a","b","c","d"])

# %%
pd.DataFrame({"C1":s1,"C2":s2})
# Out:
#    C1  C2
# a   1   1
# b   2   2
# c   3   3
# d   4   4

# %%
hr_data = pd.read_csv("https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/HR_comma_sep.csv.txt")

# %%
hr_data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# sales                    14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
hr_data.select_dtypes(exclude=['int64']).head(4)
# Out:
#    satisfaction_level  last_evaluation  sales  salary
# 0                0.38             0.53  sales     low
# 1                0.80             0.86  sales  medium
# 2                0.11             0.88  sales  medium
# 3                0.72             0.87  sales     low

# %% [markdown]
# Selecting the subset of coulmn

# %%
type(hr_data.salary)
# Out:
# pandas.core.series.Series

# %%
type(hr_data[['salary','left']])
# Out:
# pandas.core.frame.DataFrame

# %%
hr_data[["salary","left"]].head(5)
# Out:
#    salary  left
# 0     low     1
# 1  medium     1
# 2  medium     1
# 3     low     1
# 4     low     1

# %%
hr_data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
hr_data.satisfaction_level.mean(
)
# Out:
# 0.6128335222348166

# %%
hr_data.satisfaction_level.std()
# Out:
# 0.2486306510611418

# %%
hr_data.left.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
hr_data.sales.unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
hr_data.rename(columns = {'sales':'Department'}, inplace = True)

# %%
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# Department               14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.3+ MB

# %%
hr_data.Department.value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: Department, dtype: int64

# %%
hr_data.salary.value_counts()
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
###identifying the missing values

# %%
tt = pd.read_csv("https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/titanic-train.csv.txt")

# %%
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
tt[tt.Age.isnull()].head()`b
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %%
tt[tt.Age.isnull()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %%
### to print the first 3 values of the column
import pandas as pd
s = pd.read_csv("https://raw.githubusercontent.com/edyoda/Data-Scientist-program/master/Practice%20Problems/data/winemag.csv", encoding="latin")

s.head(5)
# Out:
#    Unnamed: 0   country                                        description  \
# 0         0.0     Italy  Aromas include tropical fruit, broom, brimston...
# 1         1.0  Portugal  This is ripe and fruity, a wine that is smooth...
# 2         2.0        US  Tart and snappy, the flavors of lime flesh and...
# 3         3.0        US  Pineapple rind, lemon pith and orange blossom ...
# 4         4.0        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  Unnamed: 5           province  \
# 0                       Vulkï¿½ï¿½ Bi    87.0         NaN  Sicily & Sardinia
# 1                            Avidagos    87.0         NaN              Douro
# 2                                 NaN    87.0         NaN             Oregon
# 3                Reserve Late Harvest    87.0         NaN           Michigan
# 4  Vintner's Reserve Wild Child Block    87.0         NaN             Oregon
#
# ...

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129868 entries, 0 to 129867
# Data columns (total 12 columns):
# Unnamed: 0     79338 non-null float64
# country        79302 non-null object
# description    79338 non-null object
# designation    56432 non-null object
# points         79338 non-null float64
# Unnamed: 5     0 non-null float64
# province       79302 non-null object
# region_1       66395 non-null object
# region_2       30525 non-null object
# Unnamed: 9     0 non-null float64
# Unnamed: 10    0 non-null float64
# Unnamed: 11    0 non-null float64
# dtypes: float64(6), object(6)
# memory usage: 11.9+ MB

# %%
s[s.points.isnull()].head(5)
# Out:
#        Unnamed: 0 country description designation  points  Unnamed: 5  \
# 79338         NaN     NaN         NaN         NaN     NaN         NaN
# 79339         NaN     NaN         NaN         NaN     NaN         NaN
# 79340         NaN     NaN         NaN         NaN     NaN         NaN
# 79341         NaN     NaN         NaN         NaN     NaN         NaN
# 79342         NaN     NaN         NaN         NaN     NaN         NaN
#
#       province region_1 region_2  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 79338      NaN      NaN      NaN         NaN          NaN          NaN
# 79339      NaN      NaN      NaN         NaN          NaN          NaN
# 79340      NaN      NaN      NaN         NaN          NaN          NaN
# 79341      NaN      NaN      NaN         NaN          NaN          NaN
# 79342      NaN      NaN      NaN         NaN          NaN          NaN

# %%
### to print the first 3 values of the column
import pandas as pd
s = pd.read_csv("https://raw.githubusercontent.com/edyoda/Data-Scientist-program/master/Practice%20Problems/data/winemag.csv", encoding="latin")
desc = s[["description"]]
desc.head(5)
# Out:
#                                          description
# 0  Aromas include tropical fruit, broom, brimston...
# 1  This is ripe and fruity, a wine that is smooth...
# 2  Tart and snappy, the flavors of lime flesh and...
# 3  Pineapple rind, lemon pith and orange blossom ...
# 4  Much like the regular bottling from 2012, this...

# %%
s.points.value_counts()
# Out:
# 87.0     10709
# 88.0     10241
# 90.0      9404
# 86.0      7671
# 89.0      7301
# 91.0      7179
# 85.0      6107
# 92.0      5782
# 84.0      4082
# 93.0      3882
# 94.0      2408
# 83.0      1724
# 82.0       999
# 95.0       843
# 81.0       354
# 96.0       298
# 80.0       181
# 97.0       107
# 98.0        42
# 99.0        16
# 100.0        8
# Name: points, dtype: int64

# %%
s.region_1.value_counts()
# Out:
# Napa Valley                          2699
# Columbia Valley (WA)                 2465
# Russian River Valley                 1875
# California                           1582
# Willamette Valley                    1461
#                                      ...
# York Mountain                           1
# Kentucky                                1
# Vin de Pays des Maures                  1
# Gundagai                                1
# Valpolicella Valpantena Superiore       1
# Name: region_1, Length: 1146, dtype: int64

# %%
### to print the last values of the coulmn
desc.tail(5)
# Out:
#        description
# 129863         NaN
# 129864         NaN
# 129865         NaN
# 129866         NaN
# 129867         NaN

# %%
### Read Headers:
print(s.columns)
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'Unnamed: 5', 'province', 'region_1', 'region_2', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %%
### To Read the columns
print(s[["region_1"]]) #This is a Data Frame
s.region_1  # This is a Series)
# Out:
#                    region_1
# 0                      Etna
# 1                       NaN
# 2         Willamette Valley
# 3       Lake Michigan Shore
# 4         Willamette Valley
# ...                     ...
# 129863                  NaN
# 129864                  NaN
# 129865                  NaN
# 129866                  NaN
# 129867                  NaN
#
# [129868 rows x 1 columns]
# 0                        Etna
# 1                         NaN
# 2           Willamette Valley
# 3         Lake Michigan Shore
# 4           Willamette Valley
#                  ...
# 129863                    NaN
# 129864                    NaN
# 129865                    NaN
# 129866                    NaN
# 129867                    NaN
# Name: region_1, Length: 129868, dtype: object

# %%
for index, row in s.iterrows():
    print(index, row["country"])
# Out:
# 0 Italy
# 1 Portugal
# 2 US
# 3 US
# 4 US
# 5 Spain
# 6 Italy
# 7 France
# 8 Germany
# 9 France
# 10 US
# 11 France
# 12 US
# 13 Italy
# 14 US
# 15 Germany
# 16 Argentina
# 17 Argentina
# 18 Spain
# 19 US
# 20 US
# 21 US
# 22 Italy
# 23 US
# 24 Italy
# 25 US
# 26 Italy
# 27 Italy
# 28 Italy
# 29 US
# 30 France
# 31 Italy
# 32 Italy
# 33 US
# 34 US
# 35 US
# 36 Chile
# 37 Italy
# 38 Italy
# 39 Italy
# 40 Italy
# 41 US
# 42 France
# 43 US
# 44 Chile
# 45 US
# 46 Italy
# 47 US
# 48 US
# 49 France
# 50 Italy
# 51 Chile
# 52 Italy
# 53 France
# 54 Italy
# 55 US
# 56 US
# 57 Italy
# 58 Chile
# 59 US
# 60 US
# 61 Italy
# 62 US
# 63 France
# 64 US
# 65 France
# 66 France
# 67 US
# 68 US
# 69 France
# 70 US
# 71 US
# 72 Italy
# 73 US
# 74 US
# 75 US
# 76 Germany
# 77 Australia
# 78 US
# 79 Portugal
# 80 Chile
# 81 Spain
# 82 France
# 83 Australia
# 84 US
# 85 Germany
# 86 US
# 87 US
# 88 Italy
# 89 Italy
# 90 US
# 91 US
# 92 US
# 93 Austria
# 94 US
# 95 France
# 96 France
# 97 US
# 98 Italy
# ...
